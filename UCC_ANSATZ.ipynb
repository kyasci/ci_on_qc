# %% [markdown]
# # Quantum Circuits
# Quantum computers can only use a specific set of gates (universal gate set). Given the entanglers and their amplitudes found in Step 3, one can find corresponding representation of these operators in terms of elementary gates using the following procedure.

# %%
from qiskit import IBMQ, Aer, execute
IBMQ.enable_account("852f8ac107a38643d0f46a1faee2f9feeb7102d343d51f029ac18fdf3778c071a673fdf921e59d272cfa2876c381631eccc8133279a4d98c69f13dafed79348d")
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
import numpy as np
import tequila as tq
from utility import *

threshold = 1e-6 
tol=threshold

# %% [markdown]
# First, we set up the Hamiltonian in Tequila's format and the unitary gates obtained in Step 3.

# %%
R=1.5
bond_lengths = np.linspace(0.4,2.4,10)

molecule='h2'
basis='sto-3g'
qubit_transf='jw' 

#Define number of entanglers to enter ansatz
n_ents = 1

# %%
estimate1=[]
satring_e=[]
U_QCC_e=[]
CO_QCC_e=[]
QCC_energy=[]
IBM_QC_e=[]

for R in bond_lengths:

#Quantum Chemistry methods

    xyz_data = get_molecular_data(molecule, geometry=R, xyz_format=True)
    hm = tq.quantumchemistry.Molecule(geometry=xyz_data, basis_set=basis)

    print('Number of spin-orbitals (qubits): {} \n'.format(2*hm.n_orbitals))

    #e0=hm.compute_energy(method='cisd') #VGG problem for H2
    e0=obtain_PES(molecule,[R], basis=basis,  method='fci')
    hf_reference = hf_occ(2*hm.n_orbitals, hm.n_electrons)
    H = hm.make_hamiltonian()

##Got the first estimate for the energy

    estimate1.append(e0)
    print('FCI energy: {}'.format(e0))
    print("\nHamiltonian has {} terms\n".format(len(H)))

    #Rank entanglers using energy gradient criterion
    ranked_entangler_groupings = generate_QCC_gradient_groupings(H.to_openfermion(), 
                                                                 2*hm.n_orbitals, 
                                                                 hf_reference, 
                                                                 cutoff=threshold)

    print('Grouping gradient magnitudes (Grouping : Gradient magnitude):')
    for i in range(len(ranked_entangler_groupings)):
        print('{} : {}'.format(i+1,ranked_entangler_groupings[i][1]))

    entanglers = get_QCC_entanglers(ranked_entangler_groupings, n_ents, 2*hm.n_orbitals)

    print('\nSelected entanglers:')
    for ent in entanglers:
        print(ent)

    #Mean-field part of U (Omega):    
    U_MF = construct_QMF_ansatz(n_qubits = 2*hm.n_orbitals)

    #Entangling part of U:
    U_ENT = construct_QCC_ansatz(entanglers)

    U_QCC = U_MF + U_ENT

    E = tq.ExpectationValue(H=H, U=U_QCC)

    initial_vals = init_qcc_params(hf_reference, E.extract_variables())

##Got the initial energy estimate based on HF for QCC
    satring_e.append(tq.simulate(E, variables=initial_vals))

    #Minimize wrt the entangler amplitude and MF angles:
    result = tq.minimize(objective=E, method="BFGS", initial_values=initial_vals, tol=tol)
    U_QCC_e.append(result.energy)
    
##Got the optimization estimate based on U_QCC
    print('\nObtained QCC energy ({} entanglers): {}'.format(len(entanglers), result.energy))


#QC based methods - the VQE

    H_q = tq.QubitHamiltonian.from_openfermion(get_qubit_hamiltonian(
        molecule, R, basis, qubit_transf=qubit_transf)) 

    stating_angels=result.angles
    vars={str(kw):stating_angels[kw] for kw in stating_angels}

    n_qubits=2*hm.n_orbitals

    a = tq.Variable("tau_0")
    U = construct_QMF_ansatz(n_qubits)
    U += tq.gates.ExpPauli(paulistring=tq.PauliString.from_string("X(0)Y(1)X(2)X(3)"), angle=a)
    
    E_q = tq.ExpectationValue(H=H_q, U=U)

#Perform VQE if feasable

    #Minimize wrt the entangler amplitude and MF angles:
    #result_q = tq.minimize(objective=E_q, method="BFGS", initial_values=vars, tol=tol)
    #CO_QCC_e.append(result_q.energy)
    #stating_angels=result_q.angles
    #vars={str(kw):stating_angels[kw] for kw in stating_angels}
    
    e_q=tq.simulate(E_q, variables=vars)
    QCC_energy.append(e_q)

#Got the circuit energy    
    print()
    print(U)
    print(vars)
    print("Energy:",e_q)


    # list of devices available can be found in ibmq account page
    #backend = Aer.get_backend('qasm_simulator')
    # %time 
    q_result=tq.simulate(E_q, variables=vars, samples=100, backend="qiskit", device='ibmq_qasm_simulator')
    IBM_QC_e.append(q_result)
    
    print("QC_device:",q_result)
    print()
# Out:
# Number of spin-orbitals (qubits): 4
#
# E = -0.9141497050119503 Eh
# FCI energy: [-0.91414971]
#
# Hamiltonian has 15 terms
#
# Grouping gradient magnitudes (Grouping : Gradient magnitude):
# 1 : 0.1645
#
# Selected entanglers:
# 1.0 [X0 Y1 X2 X3]
# Optimizer: <class 'tequila.optimizers.optimizer_scipy.OptimizerSciPy'>
# backend         : qulacs
# samples         : None
# save_history    : True
# noise           : None
#
# Method          : BFGS
# Objective       : 1 expectationvalues
# gradient        : 18 expectationvalues
#
# active variables : 9
#
# E=-0.90436139  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.0}  samples= None
# E=-0.91270369  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.164515420794487}  samples= None
# E=-0.91414970  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.1187892950058281}  samples= None
# E=-0.91414971  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.11885555249909908}  samples= None
# Optimization terminated successfully.
#          Current function value: -0.914150
#          Iterations: 3
#          Function evaluations: 4
#          Gradient evaluations: 4
#
# Obtained QCC energy (1 entanglers): -0.9141497050119456
#
# circuit:
# Rx(target=(0,), parameter=beta_0)
# Rz(target=(0,), parameter=gamma_0)
# Rx(target=(1,), parameter=beta_1)
# Rz(target=(1,), parameter=gamma_1)
# Rx(target=(2,), parameter=beta_2)
# Rz(target=(2,), parameter=gamma_2)
# Rx(target=(3,), parameter=beta_3)
# Rz(target=(3,), parameter=gamma_3)
# Exp-Pauli(target=(0, 1, 2, 3), control=(), parameter=tau_0, paulistring=X(0)Y(1)X(2)X(3))
#
# {'beta_0': 3.141592653589793, 'gamma_0': 0.0, 'beta_1': 3.141592653589793, 'gamma_1': 0.0, 'beta_2': 0.0, 'gamma_2': 0.0, 'beta_3': 0.0, 'gamma_3': 0.0, 'tau_0': 0.11885555249909908}
# Energy: -0.9141497046270801
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 24.8 µs
# QC_device: -0.9183452052054576
#
# Number of spin-orbitals (qubits): 4
#
# E = -1.123397288736203 Eh
# FCI energy: [-1.12339729]
#
# Hamiltonian has 15 terms
#
# Grouping gradient magnitudes (Grouping : Gradient magnitude):
# 1 : 0.1749
#
# Selected entanglers:
# 1.0 [X0 Y1 X2 X3]
# Optimizer: <class 'tequila.optimizers.optimizer_scipy.OptimizerSciPy'>
# backend         : qulacs
# samples         : None
# save_history    : True
# noise           : None
#
# Method          : BFGS
# Objective       : 1 expectationvalues
# gradient        : 18 expectationvalues
#
# active variables : 9
#
# E=-1.10748331  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.0}  samples= None
# E=-1.12337592  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.17486873269081116}  samples= None
# E=-1.12339729  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.1815485448536497}  samples= None
# E=-1.12339729  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.18151051214793146}  samples= None
# Optimization terminated successfully.
#          Current function value: -1.123397
#          Iterations: 3
#          Function evaluations: 4
#          Gradient evaluations: 4
#
# Obtained QCC energy (1 entanglers): -1.123397288736198
#
# circuit:
# Rx(target=(0,), parameter=beta_0)
# Rz(target=(0,), parameter=gamma_0)
# Rx(target=(1,), parameter=beta_1)
# Rz(target=(1,), parameter=gamma_1)
# Rx(target=(2,), parameter=beta_2)
# Rz(target=(2,), parameter=gamma_2)
# Rx(target=(3,), parameter=beta_3)
# Rz(target=(3,), parameter=gamma_3)
# Exp-Pauli(target=(0, 1, 2, 3), control=(), parameter=tau_0, paulistring=X(0)Y(1)X(2)X(3))
#
# {'beta_0': 3.141592653589793, 'gamma_0': 0.0, 'beta_1': 3.141592653589793, 'gamma_1': 0.0, 'beta_2': 0.0, 'gamma_2': 0.0, 'beta_3': 0.0, 'gamma_3': 0.0, 'tau_0': 0.18151051214793146}
# Energy: -1.123397288660202
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 16.9 µs
# QC_device: -1.132929012206162
#
# Number of spin-orbitals (qubits): 4
#
# E = -1.129116926269813 Eh
# FCI energy: [-1.12911693]
#
# Hamiltonian has 15 terms
#
# Grouping gradient magnitudes (Grouping : Gradient magnitude):
# 1 : 0.1872
#
# Selected entanglers:
# 1.0 [X0 Y1 X2 X3]
# Optimizer: <class 'tequila.optimizers.optimizer_scipy.OptimizerSciPy'>
# backend         : qulacs
# samples         : None
# save_history    : True
# noise           : None
#
# Method          : BFGS
# Objective       : 1 expectationvalues
# gradient        : 18 expectationvalues
#
# active variables : 9
#
# E=-1.10356092  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.0}  samples= None
# E=-1.12664893  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.18723194301128387}  samples= None
# E=-1.12911627  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.2726803553926882}  samples= None
# E=-1.12911693  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.27130941608189374}  samples= None
# E=-1.12911693  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.271311079636129}  samples= None
# Optimization terminated successfully.
#          Current function value: -1.129117
#          Iterations: 4
#          Function evaluations: 5
#          Gradient evaluations: 5
#
# Obtained QCC energy (1 entanglers): -1.129116926269809
#
# circuit:
# Rx(target=(0,), parameter=beta_0)
# Rz(target=(0,), parameter=gamma_0)
# Rx(target=(1,), parameter=beta_1)
# Rz(target=(1,), parameter=gamma_1)
# Rx(target=(2,), parameter=beta_2)
# Rz(target=(2,), parameter=gamma_2)
# Rx(target=(3,), parameter=beta_3)
# Rz(target=(3,), parameter=gamma_3)
# Exp-Pauli(target=(0, 1, 2, 3), control=(), parameter=tau_0, paulistring=X(0)Y(1)X(2)X(3))
#
# {'beta_0': 3.141592653589793, 'gamma_0': 0.0, 'beta_1': 3.141592653589793, 'gamma_1': 0.0, 'beta_2': 0.0, 'gamma_2': 0.0, 'beta_3': 0.0, 'gamma_3': 0.0, 'tau_0': 0.271311079636129}
# Energy: -1.1291169263171845
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 20.5 µs
# QC_device: -1.1467276310838506
#
# Number of spin-orbitals (qubits): 4
#
# E = -1.0866515504266832 Eh
# FCI energy: [-1.08665155]
#
# Hamiltonian has 15 terms
#
# Grouping gradient magnitudes (Grouping : Gradient magnitude):
# 1 : 0.2011
#
# Selected entanglers:
# 1.0 [X0 Y1 X2 X3]
# Optimizer: <class 'tequila.optimizers.optimizer_scipy.OptimizerSciPy'>
# backend         : qulacs
# samples         : None
# save_history    : True
# noise           : None
#
# Method          : BFGS
# Objective       : 1 expectationvalues
# gradient        : 18 expectationvalues
#
# active variables : 9
#
# E=-1.04668029  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.0}  samples= None
# E=-1.07704938  angles= {beta_0: 3.1415926237874707, gamma_0: 0.0, beta_1: 3.1415926237874707, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.20105913281440735}  samples= None
# E=-1.08663647  angles= {beta_0: 3.1415926237874707, gamma_0: 0.0, beta_1: 3.1415926237874707, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.4000651109083546}  samples= None
# E=-1.08665155  angles= {beta_0: 3.1415926237874707, gamma_0: 0.0, beta_1: 3.1415926237874707, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.3924450354741324}  samples= None
# E=-1.08665155  angles= {beta_0: 3.1415926237874707, gamma_0: 0.0, beta_1: 3.1415926237874707, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.3924896550091631}  samples= None
# Optimization terminated successfully.
#          Current function value: -1.086652
#          Iterations: 4
#          Function evaluations: 5
#          Gradient evaluations: 5
#
# Obtained QCC energy (1 entanglers): -1.08665155042668
#
# circuit:
# Rx(target=(0,), parameter=beta_0)
# Rz(target=(0,), parameter=gamma_0)
# Rx(target=(1,), parameter=beta_1)
# Rz(target=(1,), parameter=gamma_1)
# Rx(target=(2,), parameter=beta_2)
# Rz(target=(2,), parameter=gamma_2)
# Rx(target=(3,), parameter=beta_3)
# Rz(target=(3,), parameter=gamma_3)
# Exp-Pauli(target=(0, 1, 2, 3), control=(), parameter=tau_0, paulistring=X(0)Y(1)X(2)X(3))
#
# {'beta_0': 3.1415926237874707, 'gamma_0': 0.0, 'beta_1': 3.1415926237874707, 'gamma_1': 0.0, 'beta_2': 0.0, 'gamma_2': 0.0, 'beta_3': 0.0, 'gamma_3': 0.0, 'tau_0': 0.3924896550091631}
# Energy: -1.0866515505461478
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 20.5 µs
# QC_device: -1.0890846446736286
#
# Number of spin-orbitals (qubits): 4
#
# E = -1.0375042377702628 Eh
# FCI energy: [-1.03750424]
#
# Hamiltonian has 15 terms
#
# Grouping gradient magnitudes (Grouping : Gradient magnitude):
# 1 : 0.2157
#
# Selected entanglers:
# 1.0 [X0 Y1 X2 X3]
# Optimizer: <class 'tequila.optimizers.optimizer_scipy.OptimizerSciPy'>
# backend         : qulacs
# samples         : None
# save_history    : True
# noise           : None
#
# Method          : BFGS
# Objective       : 1 expectationvalues
# gradient        : 18 expectationvalues
#
# active variables : 9
#
# E=-0.97666206  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.0}  samples= None
# E=-1.01466810  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.21568092703819275}  samples= None
# E=-1.03732585  angles= {beta_0: 3.14159257354331, gamma_0: 0.0, beta_1: 3.14159257354331, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.5793004828090227}  samples= None
# E=-1.03750419  angles= {beta_0: 3.141592577675888, gamma_0: 0.0, beta_1: 3.141592577675888, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.5493928028320225}  samples= None
# E=-1.03750424  angles= {beta_0: 3.141592606905154, gamma_0: 0.0, beta_1: 3.141592606905154, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.5498978520246526}  samples= None
# Optimization terminated successfully.
#          Current function value: -1.037504
#          Iterations: 4
#          Function evaluations: 5
#          Gradient evaluations: 5
#
# Obtained QCC energy (1 entanglers): -1.037504237770256
#
# circuit:
# Rx(target=(0,), parameter=beta_0)
# Rz(target=(0,), parameter=gamma_0)
# Rx(target=(1,), parameter=beta_1)
# Rz(target=(1,), parameter=gamma_1)
# Rx(target=(2,), parameter=beta_2)
# Rz(target=(2,), parameter=gamma_2)
# Rx(target=(3,), parameter=beta_3)
# Rz(target=(3,), parameter=gamma_3)
# Exp-Pauli(target=(0, 1, 2, 3), control=(), parameter=tau_0, paulistring=X(0)Y(1)X(2)X(3))
#
# {'beta_0': 3.141592606905154, 'gamma_0': 0.0, 'beta_1': 3.141592606905154, 'gamma_1': 0.0, 'beta_2': 0.0, 'gamma_2': 0.0, 'beta_3': 0.0, 'gamma_3': 0.0, 'tau_0': 0.5498978520246526}
# Energy: -1.0375042379002268
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 21 µs
# QC_device: -1.05116263308654
#
# Number of spin-orbitals (qubits): 4
#
# E = -0.9963864027360487 Eh
# FCI energy: [-0.9963864]
#
# Hamiltonian has 15 terms
#
# Grouping gradient magnitudes (Grouping : Gradient magnitude):
# 1 : 0.2303
#
# Selected entanglers:
# 1.0 [X0 Y1 X2 X3]
# Optimizer: <class 'tequila.optimizers.optimizer_scipy.OptimizerSciPy'>
# backend         : qulacs
# samples         : None
# save_history    : True
# noise           : None
#
# Method          : BFGS
# Objective       : 1 expectationvalues
# gradient        : 18 expectationvalues
#
# active variables : 9
#
# E=-0.90755690  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.0}  samples= None
# E=-0.95340217  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.2302514612674713}  samples= None
# E=-0.99594006  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.7874333678861614}  samples= None
# E=-0.99638571  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.7343881522604069}  samples= None
# E=-0.99638640  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.7364001419897949}  samples= None
# Optimization terminated successfully.
#          Current function value: -0.996386
#          Iterations: 4
#          Function evaluations: 5
#          Gradient evaluations: 5
#
# Obtained QCC energy (1 entanglers): -0.9963864027359435
#
# circuit:
# Rx(target=(0,), parameter=beta_0)
# Rz(target=(0,), parameter=gamma_0)
# Rx(target=(1,), parameter=beta_1)
# Rz(target=(1,), parameter=gamma_1)
# Rx(target=(2,), parameter=beta_2)
# Rz(target=(2,), parameter=gamma_2)
# Rx(target=(3,), parameter=beta_3)
# Rz(target=(3,), parameter=gamma_3)
# Exp-Pauli(target=(0, 1, 2, 3), control=(), parameter=tau_0, paulistring=X(0)Y(1)X(2)X(3))
#
# {'beta_0': 3.141592653589793, 'gamma_0': 0.0, 'beta_1': 3.141592653589793, 'gamma_1': 0.0, 'beta_2': 0.0, 'gamma_2': 0.0, 'beta_3': 0.0, 'gamma_3': 0.0, 'tau_0': 0.7364001419897949}
# Energy: -0.9963864028464245
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 24.1 µs
# QC_device: -0.9987662336283574
#
# Number of spin-orbitals (qubits): 4
#
# E = -0.9679661810238857 Eh
# FCI energy: [-0.96796618]
#
# Hamiltonian has 15 terms
#
# Grouping gradient magnitudes (Grouping : Gradient magnitude):
# 1 : 0.2441
#
# Selected entanglers:
# 1.0 [X0 Y1 X2 X3]
# Optimizer: <class 'tequila.optimizers.optimizer_scipy.OptimizerSciPy'>
# backend         : qulacs
# samples         : None
# save_history    : True
# noise           : None
#
# Method          : BFGS
# Objective       : 1 expectationvalues
# gradient        : 18 expectationvalues
#
# active variables : 9
#
# E=-0.84562442  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.0}  samples= None
# E=-0.89920644  angles= {beta_0: 3.1415926237874707, gamma_0: 0.0, beta_1: 3.1415926237874707, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.24408084154129028}  samples= None
# E=-0.96563578  angles= {beta_0: 3.1415925369999016, gamma_0: 0.0, beta_1: 3.1415925369999016, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.8055022046304687}  samples= None
# E=-0.96794313  angles= {beta_0: 3.1415925602140926, gamma_0: 0.0, beta_1: 3.1415925602140926, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.9415698960716912}  samples= None
# E=-0.96796618  angles= {beta_0: 3.141592560811024, gamma_0: 0.0, beta_1: 3.141592560811024, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.9292411987459934}  samples= None
# E=-0.96796618  angles= {beta_0: 3.1415925905433943, gamma_0: 0.0, beta_1: 3.1415925905433943, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.929269568464653}  samples= None
# Optimization terminated successfully.
#          Current function value: -0.967966
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
#
# Obtained QCC energy (1 entanglers): -0.9679661810238799
#
# circuit:
# Rx(target=(0,), parameter=beta_0)
# Rz(target=(0,), parameter=gamma_0)
# Rx(target=(1,), parameter=beta_1)
# Rz(target=(1,), parameter=gamma_1)
# Rx(target=(2,), parameter=beta_2)
# Rz(target=(2,), parameter=gamma_2)
# Rx(target=(3,), parameter=beta_3)
# Rz(target=(3,), parameter=gamma_3)
# Exp-Pauli(target=(0, 1, 2, 3), control=(), parameter=tau_0, paulistring=X(0)Y(1)X(2)X(3))
#
# {'beta_0': 3.1415925905433943, 'gamma_0': 0.0, 'beta_1': 3.1415925905433943, 'gamma_1': 0.0, 'beta_2': 0.0, 'gamma_2': 0.0, 'beta_3': 0.0, 'gamma_3': 0.0, 'tau_0': 0.929269568464653}
# Energy: -0.967966181102316
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 22.2 µs
# QC_device: -0.9772707762159665
#
# Number of spin-orbitals (qubits): 4
#
# E = -0.9509764711844851 Eh
# FCI energy: [-0.95097647]
#
# Hamiltonian has 15 terms
#
# Grouping gradient magnitudes (Grouping : Gradient magnitude):
# 1 : 0.2568
#
# Selected entanglers:
# 1.0 [X0 Y1 X2 X3]
# Optimizer: <class 'tequila.optimizers.optimizer_scipy.OptimizerSciPy'>
# backend         : qulacs
# samples         : None
# save_history    : True
# noise           : None
#
# Method          : BFGS
# Objective       : 1 expectationvalues
# gradient        : 18 expectationvalues
#
# active variables : 9
#
# E=-0.79312443  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.0}  samples= None
# E=-0.85406966  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.2567594051361084}  samples= None
# E=-0.94024040  angles= {beta_0: 3.141592574480568, gamma_0: 0.0, beta_1: 3.141592574480568, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.8284144516797085}  samples= None
# E=-0.95062075  angles= {beta_0: 3.1415925932364517, gamma_0: 0.0, beta_1: 3.1415925932364517, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 1.15217187367608}  samples= None
# E=-0.95097646  angles= {beta_0: 3.1415926201280766, gamma_0: 0.0, beta_1: 3.1415926201280766, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 1.1019284441412216}  samples= None
# E=-0.95097649  angles= {beta_0: 3.1415926496557764, gamma_0: 0.0, beta_1: 3.1415926496557764, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 1.1024415403095886}  samples= None
# Optimization terminated successfully.
#          Current function value: -0.950976
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
#
# Obtained QCC energy (1 entanglers): -0.9509764946819198
#
# circuit:
# Rx(target=(0,), parameter=beta_0)
# Rz(target=(0,), parameter=gamma_0)
# Rx(target=(1,), parameter=beta_1)
# Rz(target=(1,), parameter=gamma_1)
# Rx(target=(2,), parameter=beta_2)
# Rz(target=(2,), parameter=gamma_2)
# Rx(target=(3,), parameter=beta_3)
# Rz(target=(3,), parameter=gamma_3)
# Exp-Pauli(target=(0, 1, 2, 3), control=(), parameter=tau_0, paulistring=X(0)Y(1)X(2)X(3))
#
# {'beta_0': 3.1415926496557764, 'gamma_0': 0.0, 'beta_1': 3.1415926496557764, 'gamma_1': 0.0, 'beta_2': 0.0, 'gamma_2': 0.0, 'beta_3': 0.0, 'gamma_3': 0.0, 'tau_0': 1.1024415403095886}
# Energy: -0.9509764947360823
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 20.5 µs
# QC_device: -0.9561206774311916
#
# Number of spin-orbitals (qubits): 4
#
# E = -0.9418422354391647 Eh
# FCI energy: [-0.94184224]
#
# Hamiltonian has 15 terms
#
# Grouping gradient magnitudes (Grouping : Gradient magnitude):
# 1 : 0.2681
#
# Selected entanglers:
# 1.0 [X0 Y1 X2 X3]
# Optimizer: <class 'tequila.optimizers.optimizer_scipy.OptimizerSciPy'>
# backend         : qulacs
# samples         : None
# save_history    : True
# noise           : None
#
# Method          : BFGS
# Objective       : 1 expectationvalues
# gradient        : 18 expectationvalues
#
# active variables : 9
#
# E=-0.75019812  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.0}  samples= None
# E=-0.81794746  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.26811301708221436}  samples= None
# E=-0.92069357  angles= {beta_0: 3.141592579253089, gamma_0: 0.0, beta_1: 3.141592579253089, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.8523712236114568}  samples= None
# E=-0.94024916  angles= {beta_0: 3.141592596577025, gamma_0: 0.0, beta_1: 3.141592596577025, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 1.347251119153995}  samples= None
# E=-0.94184169  angles= {beta_0: 3.141592622596789, gamma_0: 0.0, beta_1: 3.141592622596789, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 1.239197610279448}  samples= None
# E=-0.94184224  angles= {beta_0: 3.1415926226657778, gamma_0: 0.0, beta_1: 3.1415926226657778, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 1.2411683632879322}  samples= None
# E=-0.94184224  angles= {beta_0: 3.1415926226656525, gamma_0: 0.0, beta_1: 3.1415926226656525, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 1.241164787367221}  samples= None
# Optimization terminated successfully.
#          Current function value: -0.941842
#          Iterations: 6
#          Function evaluations: 7
#          Gradient evaluations: 7
#
# Obtained QCC energy (1 entanglers): -0.9418422354391611
#
# circuit:
# Rx(target=(0,), parameter=beta_0)
# Rz(target=(0,), parameter=gamma_0)
# Rx(target=(1,), parameter=beta_1)
# Rz(target=(1,), parameter=gamma_1)
# Rx(target=(2,), parameter=beta_2)
# Rz(target=(2,), parameter=gamma_2)
# Rx(target=(3,), parameter=beta_3)
# Rz(target=(3,), parameter=gamma_3)
# Exp-Pauli(target=(0, 1, 2, 3), control=(), parameter=tau_0, paulistring=X(0)Y(1)X(2)X(3))
#
# {'beta_0': 3.1415926226656525, 'gamma_0': 0.0, 'beta_1': 3.1415926226656525, 'gamma_1': 0.0, 'beta_2': 0.0, 'gamma_2': 0.0, 'beta_3': 0.0, 'gamma_3': 0.0, 'tau_0': 1.241164787367221}
# Energy: -0.9418422354694297
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 20.3 µs
# QC_device: -0.9302729834618817
#
# Number of spin-orbitals (qubits): 4
#
# E = -0.937254952993645 Eh
# FCI energy: [-0.93725495]
#
# Hamiltonian has 15 terms
#
# Grouping gradient magnitudes (Grouping : Gradient magnitude):
# 1 : 0.2781
#
# Selected entanglers:
# 1.0 [X0 Y1 X2 X3]
# Optimizer: <class 'tequila.optimizers.optimizer_scipy.OptimizerSciPy'>
# backend         : qulacs
# samples         : None
# save_history    : True
# noise           : None
#
# Method          : BFGS
# Objective       : 1 expectationvalues
# gradient        : 18 expectationvalues
#
# active variables : 9
#
# E=-0.71591006  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.0}  samples= None
# E=-0.78980809  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.27812445163726807}  samples= None
# E=-0.90645941  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.8755831305308325}  samples= None
# E=-0.93321262  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 1.5129136285813203}  samples= None
# E=-0.93725265  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 1.3403912469712036}  samples= None
# E=-0.93725495  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 1.3444272453414003}  samples= None
# E=-0.93725495  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 1.3444087622440777}  samples= None
# Optimization terminated successfully.
#          Current function value: -0.937255
#          Iterations: 6
#          Function evaluations: 7
#          Gradient evaluations: 7
#
# Obtained QCC energy (1 entanglers): -0.9372549529936431
#
# circuit:
# Rx(target=(0,), parameter=beta_0)
# Rz(target=(0,), parameter=gamma_0)
# Rx(target=(1,), parameter=beta_1)
# Rz(target=(1,), parameter=gamma_1)
# Rx(target=(2,), parameter=beta_2)
# Rz(target=(2,), parameter=gamma_2)
# Rx(target=(3,), parameter=beta_3)
# Rz(target=(3,), parameter=gamma_3)
# Exp-Pauli(target=(0, 1, 2, 3), control=(), parameter=tau_0, paulistring=X(0)Y(1)X(2)X(3))
#
# {'beta_0': 3.141592653589793, 'gamma_0': 0.0, 'beta_1': 3.141592653589793, 'gamma_1': 0.0, 'beta_2': 0.0, 'gamma_2': 0.0, 'beta_3': 0.0, 'gamma_3': 0.0, 'tau_0': 1.3444087622440777}
# Energy: -0.9372549530096275
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 23.4 µs
# QC_device: -0.9256801873752845

# %% [markdown]
# One can check the expectation value to see it is near the ground state energy.

# %%
#Plot the PESs
import matplotlib.pyplot as plt

title_text=molecule.upper()+' dissociation, basis:'+basis.upper()
plt.title(title_text)
plt.xlabel('R, Angstrom')
plt.ylabel('E, Hartree')

plt.plot(bond_lengths, estimate1, label='FCI')
#plt.scatter(bond_lengths, satring_e, label='U_QCC_start',marker='.', color='b')
#plt.scatter(bond_lengths, U_QCC_e, label='U_QCC_energy', marker='^',color='r')
#plt.scatter(bond_lengths, CO_QCC_e, label='CO_QCC_e', marker='o',color='orange')
#plt.scatter(bond_lengths, QCC_energy, label='QCC_energy', marker='+',color='g')
plt.scatter(bond_lengths, IBM_QC_e, label='IBM_QC_run',  marker='x', color='k')
plt.legend()

# %% [markdown]
# The following code block prints the circuit.

# %%
circ = tq.circuit.compiler.compile_exponential_pauli_gate(U)
tq.draw(circ, backend="qiskit")
# Out:
#      ┌────────────────────┐┌─────────────────────┐   ┌───┐                   »
# q_0: ┤ RX(f((beta_0,))_0) ├┤ RZ(f((gamma_0,))_1) ├───┤ H ├──────■────────────»
#      ├────────────────────┤├─────────────────────┤┌──┴───┴───┐┌─┴─┐          »
# q_1: ┤ RX(f((beta_1,))_2) ├┤ RZ(f((gamma_1,))_3) ├┤ RX(pi/2) ├┤ X ├──■───────»
#      ├────────────────────┤├─────────────────────┤└──┬───┬───┘└───┘┌─┴─┐     »
# q_2: ┤ RX(f((beta_2,))_4) ├┤ RZ(f((gamma_2,))_5) ├───┤ H ├─────────┤ X ├──■──»
#      ├────────────────────┤├─────────────────────┤   ├───┤         └───┘┌─┴─┐»
# q_3: ┤ RX(f((beta_3,))_6) ├┤ RZ(f((gamma_3,))_7) ├───┤ H ├──────────────┤ X ├»
#      └────────────────────┘└─────────────────────┘   └───┘              └───┘»
# c_0: ════════════════════════════════════════════════════════════════════════»
#                                                                              »
# c_1: ════════════════════════════════════════════════════════════════════════»
#                                                                              »
# c_2: ════════════════════════════════════════════════════════════════════════»
#                                                                              »
# c_3: ════════════════════════════════════════════════════════════════════════»
#                                                                              »
# «                                             ┌───┐
# «q_0: ─────────────────────────────────■──────┤ H ├────
# «                                    ┌─┴─┐┌───┴───┴───┐
# «q_1: ────────────────────────────■──┤ X ├┤ RX(-pi/2) ├
# «                               ┌─┴─┐├───┤└───────────┘
# «q_2: ───────────────────────■──┤ X ├┤ H ├─────────────
# «     ┌───────────────────┐┌─┴─┐├───┤└───┘
# «q_3: ┤ RZ(f((tau_0,))_8) ├┤ X ├┤ H ├──────────────────
# «     └───────────────────┘└───┘└───┘
# «c_0: ═════════════════════════════════════════════════
# «
# «c_1: ═════════════════════════════════════════════════
# «
# «c_2: ═════════════════════════════════════════════════
# «
# «c_3: ═════════════════════════════════════════════════
# «
